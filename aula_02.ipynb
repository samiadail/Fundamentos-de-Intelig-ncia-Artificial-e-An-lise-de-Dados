# %%
# Estruturas de dados
temperaturas = [30, 35, 39, 40, 42, 45, 38, 37]
print(temperaturas)
# Out:
# [30, 35, 39, 40, 42, 45, 38, 37]

# %%
print(temperaturas[1])
# Out:
# 35

# %%
temperaturas[0] = 35
print(temperaturas[0])
# Out:
# 35

# %%
print(f"O primeiro registro de temperaturas foi de {temperaturas[0]} graus.")
# Out:
# O primeiro registro de temperaturas foi de 30 graus.

# %%
temperaturas.append(50)
print(temperaturas)
# Out:
# [35, 35, 39, 40, 42, 45, 38, 37, 50]

# %%
temperaturas.remove(39)
print(temperaturas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 temperaturas.remove(39)
#       2 print(temperaturas)
#
# ValueError: list.remove(x): x not in list

# %%
# Criar uma nova lista ordenada

# %%
#

# %% [markdown]
# Criem uma lista e solicitem que o usuário insira informações (3 comandos input). Exibir a lista de compras.

# %%
nome_lista = input("Digite o nome da lista: ")
print(nome_lista)

informacao_1 = int(input("Digite a primeira informção: "))
lista = [informacao_1]
print(lista)

informacao_2 = int(input("Digite a segundas informação: "))
lista.append(informacao_2)
print(lista)

informacao_3 = int(input("Digite a segundas informação: "))
lista.append(informacao_3)
print(lista)
# Out:
# NOME DA LISTA
# [1]
# [1, 2]
# [1, 2, 3]
