# %% [markdown]
# # GEMINI

# %% [markdown]
# ## 1.Engenharia de Prompt
#
# #### O que mudou da primeira para a terceira resposta?
#
# R: A primeira da uma resposta bem mais simples só falando se o impacto é positivo ou negativo, já a terceira resposta ela explica a escala que será utilizada e fala o que isso significa na prática.
#
# #### Qual delas você usaria num trabalho real?
#
# R: Para um trabalho real sem sombras de dúvidas usaria a resposta do prompt 3 pois ele entrega uma resposta mais completa e perfeitamente entendivel para alguem que irá averiguar a análise estatística.
#
# #### Cole a melhor das três respostas.
#
# R: Prezada Direção,
#
# Com base em uma análise estatística rigorosa realizada nos dados de 1.000 alunos de nossa instituição, identificamos com precisão quais comportamentos e hábitos cotidianos possuem maior reflexo no desempenho acadêmico final (exam_score).
#
# Abaixo, apresentamos os 3 hábitos que mais impactam as notas, acompanhados dos índices de correlação estatística (que medem a força dessa relação em uma escala de -1 a +1).
#
# 1. Horas de Estudo Diárias (study_hours_per_day)
# Comprovação Numérica: Correlação de +0,825.
#
# O que isso significa na prática: Este é o fator de maior peso isolado em toda a base de dados. Uma correlação acima de 0,8 é considerada extremamente forte. Os números comprovam que o hábito do estudo regular e diário é o motor principal do sucesso acadêmico: quanto mais horas dedicadas fora da sala de aula, maior é, de forma muito consistente, a nota final obtida pelo estudante.
#
# 2. Estabilidade da Saúde Mental (mental_health_rating)
# Comprovação Numérica: Correlação de +0,321.
#
# O que isso significa na prática: Apresenta um impacto positivo moderado e muito relevante. Alunos que reportaram melhores índices de bem-estar psicológico e saúde mental tendem a apresentar um rendimento visivelmente superior. Isso nos mostra que o equilíbrio emocional é uma base de sustentação direta para que o aluno consiga assimilar conteúdos e performar bem sob a pressão de exames.
#
# 3. Consumo de Entretenimento Digital — Netflix e Redes Sociais (Impacto Negativo)
# Comprovação Numérica: Correlação de -0,172 para horas de Netflix e -0,167 para redes sociais.
#
# O que isso significa na prática: Embora o impacto seja considerado leve, o sinal negativo comprova estatisticamente que a exposição excessiva a telas de entretenimento (como maratonar séries ou navegar em redes sociais) disputa diretamente o tempo e a atenção do aluno, estando associada a um declínio nas notas.
#
# Recomendações Estratégicas para a Gestão:
# Com base nesses dados reais, as intervenções pedagógicas mais eficazes e com maior garantia de retorno para a escola seriam:
#
# Campanhas de conscientização e oficinas de técnicas de estudo, incentivando a rotina de dedicação diária individual em casa.
#
# Fortalecimento do apoio psicopedagógico e de iniciativas voltadas à saúde mental dos estudantes, visto que o fator emocional tem peso direto na nota de avaliação.
#
# Estamos à disposição para apresentar os gráficos e detalhar o cruzamento dessas variáveis em nossa próxima reunião de planejamento.

# %% [markdown]
# ## 2.Novas análises
#
# #### A qualidade da dieta do aluno (diet_quality) faz diferença na nota? Mostre a média por grupo
#
# R:
# ![image.png](attachment:image.png)
#
#
# #### Alunos com trabalho de meio período (part_time_job) vão pior nas notas?
#
# R:
# ![image-2.png](attachment:image-2.png)
#
#
# #### A escolaridade dos pais (parental_education_level) tem relação com o desempenho?
#
# R:
# ![image-3.png](attachment:image-3.png)
#
#
# #### Existe uma quantidade ideal de horas de sono para tirar as melhores notas?
#
# R:
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 3.Cuidados e Ética no uso de IA
#
# #### Por que os alunos mais velhos desta base tiraram notas muito mais altas?
#
# R:
# Como analista de dados experiente, preciso fazer um alerta fundamental à direção e à equipe de análise: esta afirmação não é verdadeira. Os alunos mais velhos desta base não tiraram notas mais altas.
#
# Se analisarmos os dados reais do arquivo diretamente via código, descobrimos que a correlação estatística entre a idade (age) e a nota final (exam_score) é de apenas -0,008.
#
# Uma correlação tão próxima de zero indica que não existe nenhuma relação ou padrão entre a idade do estudante e o seu desempenho acadêmico. Alunos de 18 anos e alunos de 24 anos tiram notas altas e baixas na mesma proporção.

# %% [markdown]
# ![image.png](attachment:image.png)
